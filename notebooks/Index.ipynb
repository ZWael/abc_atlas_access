# %% [markdown]
# # ABC Atlas Access — Tutorial Index
#
# This repository contains a collection of notebooks for analyzing and visualizing single-cell and spatial transcriptomics data using the ABC Atlas.
#
# ---
#
# ## 🧬 Getting Started
# - [Getting Started](getting_started.ipynb)
# - [ABC Atlas Selection Example](abc_atlas_selection_example.ipynb)
#
# ---
#
# ## 🧪 Scanpy-based Workflow
# - [Using Scanpy (MERFISH tutorial rewrite)](Using_scanpy.ipynb)
#
# ---
#
# ## 🧠 MERFISH Tutorials
# - [MERFISH Part 1](merfish_tutorial_part_1.ipynb)
# - [MERFISH Part 2a](merfish_tutorial_part_2a.ipynb)
# - [MERFISH Part 2b](merfish_tutorial_part_2b.ipynb)
# - [Zhuang MERFISH Tutorial](zhuang_merfish_tutorial.ipynb)
#
# ---
#
# ## 🧬 10x snRNA-seq Tutorials
# - [General 10x snRNA-seq](general_accessing_10x_snRNASeq_tutorial.ipynb)
# - [Consensus Mouse 10x](consensus_mouse_10X_snRNASeq.ipynb)
# - [WHB Part 1](WHB-10x_snRNASeq_tutorial_part_1.ipynb)
# - [WHB Part 2](WHB-10x_snRNASeq_tutorial_part_2.ipynb)
# - [Zeng Aging Mouse](Zeng_Aging_Mouse_10x_snRNASeq_tutorial.ipynb)
#
# ---
#
# ## 🧩 Clustering & Annotation
# - [Cluster Annotation Tutorial](cluster_annotation_tutorial.ipynb)
# - [Cluster Groups & Embeddings](cluster_groups_and_embeddings_tutorial.ipynb)
# - [Cluster Neighborhood Gallery](cluster_neighborhood_gallery.ipynb)
# - [WHB Cluster Annotation](WHB_cluster_annotation_tutorial.ipynb)
#
# ---
#
# ## 🧭 Spatial / MERFISH Advanced
# - [MERFISH CCF Registration](merfish_ccf_registration_tutorial.ipynb)
# - [MERFISH Imputed Genes](merfish_imputed_genes_example.ipynb)
#
# ---
#
# ## 🧪 Other Resources
# - [CCF & Parcellation](ccf_and_parcellation_annotation_tutorial.ipynb)
# - [Cluster Annotation (legacy)](cluster_annotation_tutorial.ipynb)
